# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
titanic = sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.lineplot(x = 'age', y='fare', data=titanic)
plt.title('Age vs Fare')
# Out:
# Text(0.5, 1.0, 'Age vs Fare')

# %%
sns.lineplot(x = 'age', y='fare', data=titanic)
plt.title('Age vs Fare')

plt.ylabel('Fare')
plt.xlabel('Age')

plt.xlim(right = 66)
plt.ylim(3,top = 150)
# Out:
# (3.0, 150.0)

# %%
sns.set_style('darkgrid')
sns.lineplot(x = 'age', y='fare', data=titanic)
plt.title('Age vs Fare')
# Out:
# Text(0.5, 1.0, 'Age vs Fare')

# %%
plt.figure(figsize=(15,4))
sns.lineplot(x = 'age', y='fare', data=titanic)
plt.title('Age vs Fare')
# Out:
# Text(0.5, 1.0, 'Age vs Fare')

# %%
plt.figure(figsize=(15,4))
sns.lineplot(x = 'age', y='fare', data=titanic, color= 'red', palette='dark')
plt.title('Age vs Fare')
# Out:
# Text(0.5, 1.0, 'Age vs Fare')

# %%
sns.barplot(x = 'who', y = 'age', data =titanic)
# Out:
# <AxesSubplot:xlabel='who', ylabel='age'>

# %%
sns.barplot(x = 'who', y = 'age', hue = 'class',data =titanic, order = ['child', 'man', 'woman'],color='green')
# Out:
# <AxesSubplot:xlabel='who', ylabel='age'>

# %%
sns.barplot(x = 'who', y = 'age', hue = 'class',data =titanic, order = ['child', 'man', 'woman'],color='green',ci = None)
# Out:
# <AxesSubplot:xlabel='who', ylabel='age'>

# %%
sns.barplot(x = 'who', y = 'age', hue = 'class',data =titanic, order = ['child', 'man', 'woman'],color='green',
ci = None, palette = 'bright')
# Out:
# <AxesSubplot:xlabel='who', ylabel='age'>

# %%
from numpy import mean
sns.barplot(x = 'who', y = 'age', hue = 'class',data =titanic, order = ['child', 'man', 'woman'],color='green',
estimator= mean, palette = 'bright')
# Out:
# <AxesSubplot:xlabel='who', ylabel='age'>

# %%
from numpy import mean
sns.barplot(x = 'who', y = 'age', hue = 'class',data =titanic, order = ['child', 'man', 'woman'],color='green',
estimator= mean, palette = 'bright',saturation= .5)
# Out:
# <AxesSubplot:xlabel='who', ylabel='age'>

# %%
plt.figure(figsize=(5,6))
sns.barplot(x = 'age', y = 'who', hue = 'class',data =titanic, order = ['child', 'man', 'woman'],color='green',
 palette = 'bright',saturation= .5)   #define catogorical variable on y axis
# Out:
# <AxesSubplot:xlabel='age', ylabel='who'>

# %%
sns.barplot(x= 'who', y= 'fare',data = titanic,
            linewidth=3,  facecolor = (1,1,.5,.6),
            errcolor = '0', edgecolor = '.8')
# Out:
# <AxesSubplot:xlabel='who', ylabel='fare'>

# %%
tip = sns.load_dataset('tips')
sns.barplot(y = tip['tip'],x = tip['day'],hue = 'smoker',data = tip, dodge=True ,color='#373aab', ci = None)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>
